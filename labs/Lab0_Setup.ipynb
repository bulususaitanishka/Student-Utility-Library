# %% [markdown]
# <a href="https://colab.research.google.com/github/bulususaitanishka/Student-Utility-Library/blob/main/labs/Lab0_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 0: Environment Setup

# %% [markdown]
# **Objective**: Set up the development environment for building AI agents
#
# In this lab, you will:
# 1. Install required Python packages
# 2. Set up GitHub Models for free LLM access
# 3. Deploy the mock backend using ngrok
#
# ---

# %% [markdown]
# ## Step 1: Install Required Packages

# %% [markdown]
# We'll install all necessary Python packages for agent development.
#
# > You may see an error message like this at the bottom, but that's okay, as long as the call is successfully excuted (there a green tick next to the cell on the left):
# > ![image.png](https://i.ibb.co/nFVsYs4/python-package-download-error.png)

# %%
# Install all required packages
# !pip install -q agent-framework --pre requests fastapi uvicorn pyngrok nest-asyncio
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.5/116.5 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.3/91.3 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.6/345.6 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.9/362.9 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.7/145.7 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.7/453.7 kB 30.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.3/274.3 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.3/218.3 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.1/451.1 kB 34.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.6/146.6 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.0/432.0 kB 29.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 80.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 MB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.9/107.9 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 MB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.1/297.1 kB 18.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.9/111.9 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 65.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 67.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.5/297.5 kB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.9/197.9 kB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.1/356.1 kB 28.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.3/197.3 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.7/435.7 kB 31.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.3/817.3 kB 41.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.3/228.3 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.9/389.9 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.4/142.4 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.5/121.5 kB 10.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.41.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.4 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.

# %% [markdown]
# ## Step 2: Configure GitHub Models Access with Colab Secrets

# %% [markdown]
# Instructions to Store Your GitHub Token Securely:
#
# **Step 2a: Get Your GitHub Personal Access Token (PAT)**
# 1. Visit https://github.com/settings/tokens?type=beta
# 2. Click "Generate new token" (fine-grained token)
# 3. Set token name (e.g., "GitHub Models Access")
# 4. Set expiration (e.g., 90 days)
# 5. Under "Permissions", select "Models"
# 6. Click "Generate token" and **COPY THE TOKEN**
#
# **Step 2b: Store in Colab Secrets (Recommended)**
# 1. Look at the left sidebar of this Colab notebook
# 2. Click the **🔑 key icon** (Secrets)
# 3. Click **"+ Add new secret"**
# 4. Name: `GITHUB_PAT`
# 5. Value: **Paste your token here**
# 6. Toggle **"Notebook access"** to ON
#
# ![Colab Secrets Location](https://colab.research.google.com/img/colab_favicon_256px.png)
#
# **Why use Secrets?**
# - Tokens are encrypted and not visible in notebook cells
# - Prevents accidental token exposure when sharing notebooks
# - Follows security best practices
#
# **Note**: GitHub Models provides free access to various LLMs for development purposes.

# %%
# Load GitHub token from Colab Secrets
from google.colab import userdata

try:
    GITHUB_PAT = userdata.get('GITHUB_PAT')
    print("✅ GitHub PAT loaded from Colab Secrets successfully!")
    print(f"✅ Token length: {len(GITHUB_PAT)} characters")
except Exception as e:
    print("⚠️ WARNING: Could not load GITHUB_PAT from Colab Secrets!")
    print("   Please follow Step 2b above to add your token to Secrets.")
    print(f"   Error: {e}")
    GITHUB_PAT = ""  # Fallback
# Out:
# ✅ GitHub PAT loaded from Colab Secrets successfully!
# ✅ Token length: 93 characters

# %% [markdown]
# ## Step 3: Test GitHub Models Connection

# %% [markdown]
# We'll test that we can connect to GitHub Models using the OpenAI Chat Completions API.

# %%
from openai import OpenAI

# %%
# Initialize OpenAI chat client with GitHub Models endpoint
client = OpenAI(
  base_url="https://models.github.ai/inference",
  api_key=GITHUB_PAT,
)

# %%
completion = client.chat.completions.create(
    model="openai/gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "What is in the meaning of life?"
                }
            ]
        }
    ],
    temperature=1.0,
    top_p=1.0,
    max_tokens=1000,
)

# %%
print(completion.choices[0].message.content)
# Out:
# The meaning of life is a profound and complex question that has been explored by philosophers, theologians, scientists, and thinkers throughout history. Answers vary widely depending on cultural, religious, and personal beliefs. Here are a few perspectives:
#
# 1. **Philosophical Views**: Some philosophers suggest that life’s meaning is subjective and must be created by individuals based on their experiences, relationships, and values. Existentialists, for example, argue that meaning is not predetermined and must be found through personal choice and action.
#
# 2. **Religious Perspectives**: Many religions provide their own interpretations of life's purpose. For instance, in Christianity, life’s purpose might involve serving God and following the teachings of Jesus. In Buddhism, the goal might be to attain enlightenment and escape the cycle of suffering.
#
# 3. **Scientific Outlook**: From a biological perspective, the purpose of life can be seen as survival and reproduction. Evolutionary biology focuses on the continuation of genes and species, while neuroscience may explore how consciousness and self-awareness contribute to our understanding of existence.
#
# 4. **Psychological Insights**: Some psychologists emphasize the importance of finding meaning through connections with others, personal growth, and contributing to the well-being of others. Viktor Frankl, a psychologist and Holocaust survivor, argued that meaning can be found even in the most difficult circumstances.
#
# 5. **Personal Interpretation**: Ultimately, many people find meaning through their passions, relationships, experiences, and contributions to society. Some might focus on achieving happiness, helping others, pursuing knowledge, or creating art.
#
# In essence, the question of life’s meaning invites a deeply personal exploration that can evolve over time and through various life experiences.

# %% [markdown]
# ## Step 4: Download & Deploy Mock Backend with ngrok

# %% [markdown]
# We'll download the FastAPI backend from the repository and deploy it using ngrok to create a public URL.
#
# **What happens here:**
# - Downloads `mock_backend.py` from GitHub to Colab's `/content/` directory (default working directory)
# - Starts the FastAPI server in the background (runs on port 8000)
# - Creates a public URL via ngrok for external access
# - You can access the file at `/content/mock_backend.py` if needed

# %% [markdown]
# ### Step 4a: Download & Save the Mock Backend

# %%
import nest_asyncio
from pyngrok import ngrok
import time
import requests

# %%
# Allow nested event loops (required for Colab)
# nest_asyncio.apply()

# Download the mock backend from GitHub
backend_url = "https://raw.githubusercontent.com/tezansahu/building-eval-driven-ai-agents/main/backend/mock_backend.py"

print("📥 Downloading mock backend from repository...")
response = requests.get(backend_url)

# Save to /content/ directory (Colab's default working directory)
with open('mock_backend.py', 'w') as f:
    f.write(response.text)

print("✅ Backend code downloaded to /content/mock_backend.py")
# Out:
# 📥 Downloading mock backend from repository...
# ✅ Backend code downloaded to /content/mock_backend.py

# %%
# Import the backend module
import mock_backend

# %%
# Start server in background thread
print("🚀 Starting FastAPI server...")
server_thread = mock_backend.run_in_thread(port=8000)
time.sleep(2)  # Give server time to start

print("✅ FastAPI server started on port 8000")
# Out:
# INFO:     Started server process [14755]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# 🚀 Starting FastAPI server...
# ✅ FastAPI server started on port 8000

# %% [markdown]
# ### Step 4b: Configure ngrok Authentication

# %% [markdown]
# **ngrok requires a free account and authtoken for usage.**
#
# **Instructions:**
# 1. Go to https://dashboard.ngrok.com/signup and create a free account
# 2. After signup, go to https://dashboard.ngrok.com/get-started/your-authtoken
# 3. Copy your authtoken
# 4. In Colab, click the **🔑 key icon** (Secrets) on the left sidebar
# 5. Click **"+ Add new secret"**
# 6. Name: `NGROK_AUTHTOKEN`
# 7. Value: **Paste your ngrok authtoken**
# 8. Toggle **"Notebook access"** to ON
#
# **Why ngrok?** It creates a public URL for our local backend so the agent can access it from anywhere.

# %%
try:
    NGROK_AUTHTOKEN = userdata.get('NGROK_AUTHTOKEN')
    ngrok.set_auth_token(NGROK_AUTHTOKEN)
    print("✅ ngrok authenticated successfully!")
except Exception as e:
    print("⚠️ WARNING: Could not load NGROK_AUTHTOKEN from Colab Secrets!")
    print("   Please follow the instructions above to add your ngrok authtoken.")
    print(f"   Error: {e}")
    raise
# Out:
# ✅ ngrok authenticated successfully!

# %% [markdown]
# ### Step 4c: Expose the Server Publicly

# %%
# Create public URL with ngrok
print("🌐 Creating public URL with ngrok...")
public_url = ngrok.connect(8000)
BACKEND_URL = public_url.public_url

print(f"\n{'='*60}")
print(f"✅ Backend server is running!")
print(f"{'='*60}")
print(f"📡 Public URL: {BACKEND_URL}")
print(f"📚 API Docs: {BACKEND_URL}/docs")
print(f"📂 File location: /content/mock_backend.py")
print(f"{'='*60}")
print(f"\n⚠️ IMPORTANT: Copy the Public URL above!")
print(f"   You'll need it for Lab 1")
# Out:
# 🌐 Creating public URL with ngrok...
#
# ============================================================
# ✅ Backend server is running!
# ============================================================
# 📡 Public URL: https://mulch-waltz-uranium.ngrok-free.dev
# 📚 API Docs: https://mulch-waltz-uranium.ngrok-free.dev/docs
# 📂 File location: /content/mock_backend.py
# ============================================================
#
# ⚠️ IMPORTANT: Copy the Public URL above!
#    You'll need it for Lab 1

# %% [markdown]
# ## Step 5: Test Backend API

# %% [markdown]
# Let's verify the backend is working correctly by testing the endpoints.

# %%
import requests
import json

# %%
# Test 1: Health check
response = requests.get(f"{BACKEND_URL}/")
print("Health Check:", response.json())
# Out:
# INFO:     34.125.23.7:0 - "GET / HTTP/1.1" 200 OK
# Health Check: {'status': 'healthy', 'message': 'Campus Event Management API is running', 'endpoints': {'events': '/events', 'venues': '/venues', 'notifications': '/notifications', 'docs': '/docs'}}

# %%
# Test 2: List events
response = requests.get(f"{BACKEND_URL}/events")
events = response.json()
print(f"\nFound {len(events)} events.:")
for event in events:
    print(f"  - {event['name']} on {event['date']}")
# Out:
# INFO:     34.125.23.7:0 - "GET /events HTTP/1.1" 200 OK
#
# Found 4 events.:
#   - TechFest 2024 on 2024-03-15
#   - Spring Hackathon 2024 on 2024-04-20
#   - AI & Machine Learning Workshop on 2024-03-25
#   - Robotics Club Demo Day on 2024-04-05

# %% [markdown]
# ## 🎉 Lab 0 Complete!

# %% [markdown]
# ### What You Accomplished:
#
# ✅ **Installed Microsoft Agents Framework** - A high-level library for building AI agents
# ✅ **Configured GitHub Models** - Free LLM access using GitHub PAT
# ✅ **Stored secrets securely** - Using Colab Secrets (best practice)
# ✅ **Deployed mock backend** - Campus event management API with ngrok
# ✅ **Tested the setup** - Verified agent can call LLM and backend APIs
#
# ### Key Concepts Learned:
#
# 1. **Colab Secrets**: Secure way to store API tokens without exposing them in code
# 2. **GitHub Models**: Free access to GPT-4o-mini for development
# 3. **ngrok**: Makes local services accessible via public URL
#
# ### What's Next?
#
# **Lab 1**: Build a complete campus event agent with 3 tools:
# - Register students for events
# - Book venues for clubs
# - Send notifications to participants
#
# **Lab 2**: Evaluate and improve the agent using metrics:
# - Relevance Evaluator (Azure AI)
# - Task Adherence Evaluator (Azure AI)
# - Custom Conciseness Evaluator
# - Measure improvement systematically
#
# ---

# %% [markdown]
# ## Troubleshooting:

# %% [markdown]
# **Issue**: "Could not load GITHUB_PAT from Colab Secrets"
# - **Solution**: Click 🔑 icon → Add new secret → Name: `GITHUB_PAT` → Enable notebook access
#
# **Issue**: "ngrok tunnel failed"
# - **Solution**: Re-run the ngrok cell. Tunnels expire after inactivity.
#
# **Issue**: Backend API not responding
# - **Solution**: Check that BACKEND_URL is set correctly and starts with `https://`
